# %%
import os
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import collections

# %%
values = [
    ('R0', 392, 275, 992),
    ('R1', 383, 261, 992),
    ('R2', 340, 252, 911),
    ('R3', 262, 174, 449),
    ('R4', 259, 171, 419),
    ('R5', 254, 165, 384),
]

# %%
df_sizes = pd.DataFrame(values, columns=['name', 'bare1', 'bare2', 'co'])
df_sizes
# Out:
#   name  bare1  bare2   co
# 0   R0    392    275  992
# 1   R1    383    261  992
# 2   R2    340    252  911
# 3   R3    262    174  449
# 4   R4    259    171  419
# 5   R5    254    165  384

# %%
df_sizes_norm = df_sizes.melt(id_vars='name')#, value_vars=['size', 'sss'])
df_sizes_norm
# Out:
#    name variable  value
# 0    R0    bare1    392
# 1    R1    bare1    383
# 2    R2    bare1    340
# 3    R3    bare1    262
# 4    R4    bare1    259
# 5    R5    bare1    254
# 6    R0    bare2    275
# 7    R1    bare2    261
# 8    R2    bare2    252
# 9    R3    bare2    174
# 10   R4    bare2    171
# 11   R5    bare2    165
# 12   R0       co    992
# 13   R1       co    992
# 14   R2       co    911
# 15   R3       co    449
# 16   R4       co    419
# 17   R5       co    384

# %%
fig = plt.figure(figsize=(6,4))
ax = sns.barplot(x='name', y='value', hue='variable', data=df_sizes_norm)
ax.legend(ax.legend().get_patches(), ['.git (step 1)', '.git (step 2)', '.git (step 2) + checkout'])
ax.set(xlabel='Scenario', ylabel='Size, MB')
#ax.semilogy();
ax.grid()
plt.tight_layout()
plt.savefig('graphics/cvs2git.png')
